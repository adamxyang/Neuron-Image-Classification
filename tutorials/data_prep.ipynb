# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data_prep import prepare_df, remove_bad_files

# %%
img_pth_1 = '/mnt/sdh/images_andrey/'
img_pth_2 = '/mnt/sde/stained_images/'
img_pth_3 = '/mnt/sdg/images_new/'
img_pth_4 = '/mnt/sdd/stained_images/'
df_new = prepare_df([img_pth_1, img_pth_2, img_pth_3, img_pth_4])
df_new.head()
# Out:
# Renaming files...
# Creating df...
# Available data:
# AMPROLIUM 5760
# BUCLADESINE 5760
# C07_CMP 5760
# CAMPTOTHECIN 5760
# CARBIMAZOLE 5760
# CEFAPIRIN 5759
# CHLOROPYRAZINE 5760
# CHLOROQUINE 5760
# CHRYSENEQUINONE 5760
# CYCLOPENTOLATE 5760
# DANAZOL 5760
# DIFLUNISAL 5760
# DIHYDROERGOTAMINE 5760
# DOXYLAMINE 5760
# ELLIPTICINE 5760
# ETHISTERONE 5760
# ETIDRONIC ACID 5760
# FULVESTRANT 5760
# HARPAGOSIDE 5760
# IRINOTECAN 5760
# ISOCARBOXAZID 5748
# MENADIONE 5760
# MEPHENYTOIN 3226
# METACLOPRAMIDE 5759
# OFLOXACIN 5760
# ORCIPRENALINE 5760
# OXOLAMINE 5759
# OXYBENZONE 5760
# PIPERLONGUMINE 5760
# PRES_857_LEVOBUNOLOL_PLUS 5760
# PUROMYCIN 5760
# RAUBASINE 5760
# RIFABUTIN 5760
# SANGUINARINE 5759
# THIAMPHENICOL 5760
# Sorting df (may take awhile)...
# 100%|██████████| 49767/49767 [4:44:39<00:00,  3.01it/s]
# Sorted data:
# AMPROLIUM 1440
# BUCLADESINE 1440
# C07_CMP 1440
# CAMPTOTHECIN 1440
# CARBIMAZOLE 1440
# CEFAPIRIN 1439
# CHLOROPYRAZINE 1440
# CHLOROQUINE 1440
# ...

# %%
remove_bad_files()

# %%
import pandas as pd
df = pd.read_csv('/mnt/sdh/adam/test/df_new.csv')

# %%
import numpy as np
np.unique(df.drug.tolist(), return_counts=True)
# Out:
# (array(['AMPROLIUM', 'BUCLADESINE', 'C07_CMP', 'CAMPTOTHECIN',
#         'CARBIMAZOLE', 'CEFAPIRIN', 'CHLOROPYRAZINE', 'CHLOROQUINE',
#         'CHRYSENEQUINONE', 'CYCLOPENTOLATE', 'DANAZOL', 'DIFLUNISAL',
#         'DIHYDROERGOTAMINE', 'DOXYLAMINE', 'ELLIPTICINE', 'ETHISTERONE',
#         'FULVESTRANT', 'HARPAGOSIDE', 'IRINOTECAN', 'ISOCARBOXAZID',
#         'MENADIONE', 'MEPHENYTOIN', 'METACLOPRAMIDE', 'OFLOXACIN',
#         'ORCIPRENALINE', 'OXOLAMINE', 'OXYBENZONE', 'PIPERLONGUMINE',
#         'PRES_857_LEVOBUNOLOL_PLUS', 'PUROMYCIN', 'RAUBASINE', 'RIFABUTIN',
#         'SANGUINARINE', 'THIAMPHENICOL'], dtype='<U25'),
#  array([1440, 1440, 1439, 1440, 1440, 1438, 1440, 1439, 1440, 1439, 1440,
#         1440, 1439, 1440, 1440, 1439, 1440, 1440, 1440, 1427, 1440,  806,
#         1438, 1440, 1440, 1439, 1440, 1440, 1440, 1440, 1440, 1440, 1439,
#         1440]))

# %%
list(np.unique(df.drug.tolist()))
# Out:
# ['AMPROLIUM',
#  'BUCLADESINE',
#  'C07_CMP',
#  'CAMPTOTHECIN',
#  'CARBIMAZOLE',
#  'CEFAPIRIN',
#  'CHLOROPYRAZINE',
#  'CHLOROQUINE',
#  'CHRYSENEQUINONE',
#  'CYCLOPENTOLATE',
#  'DANAZOL',
#  'DIFLUNISAL',
#  'DIHYDROERGOTAMINE',
#  'DOXYLAMINE',
#  'ELLIPTICINE',
#  'ETHISTERONE',
#  'FULVESTRANT',
#  'HARPAGOSIDE',
#  'IRINOTECAN',
#  'ISOCARBOXAZID',
#  'MENADIONE',
#  'MEPHENYTOIN',
#  'METACLOPRAMIDE',
#  'OFLOXACIN',
#  'ORCIPRENALINE',
#  'OXOLAMINE',
#  'OXYBENZONE',
#  'PIPERLONGUMINE',
#  'PRES_857_LEVOBUNOLOL_PLUS',
#  'PUROMYCIN',
#  'RAUBASINE',
#  'RIFABUTIN',
#  'SANGUINARINE',
#  'THIAMPHENICOL']
